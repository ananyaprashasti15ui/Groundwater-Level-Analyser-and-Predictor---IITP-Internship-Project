# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../../../data/raw/punjab_groundwater_telemetry.csv')

# %%
df.head()
# Out:
#    SlNo                                          Station     Agency  \
# 0     1  AMRITSAR;AJNALA;AJNALA;CHAK DOGRA;Vet. Hospital  Punjab GW
# 1     2  AMRITSAR;AJNALA;AJNALA;CHAK DOGRA;Vet. Hospital  Punjab GW
# 2     3  AMRITSAR;AJNALA;AJNALA;CHAK DOGRA;Vet. Hospital  Punjab GW
# 3     4  AMRITSAR;AJNALA;AJNALA;CHAK DOGRA;Vet. Hospital  Punjab GW
# 4     5  AMRITSAR;AJNALA;AJNALA;CHAK DOGRA;Vet. Hospital  Punjab GW
#
#    State LGD Code   State  District LGD Code  District  Tehsil   Block  \
# 0               3  Punjab                 27  AMRITSAR  AJNALA  AJNALA
# 1               3  Punjab                 27  AMRITSAR  AJNALA  AJNALA
# 2               3  Punjab                 27  AMRITSAR  AJNALA  AJNALA
# 3               3  Punjab                 27  AMRITSAR  AJNALA  AJNALA
# 4               3  Punjab                 27  AMRITSAR  AJNALA  AJNALA
#
#       Village  ... Basin Tributary Subtributary SubSubtributary Local River  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681295 entries, 0 to 681294
# Data columns (total 21 columns):
#  #   Column                                           Non-Null Count   Dtype
# ---  ------                                           --------------   -----
#  0   SlNo                                             681295 non-null  int64
#  1   Station                                          681295 non-null  object
#  2   Agency                                           681295 non-null  object
#  3   State LGD Code                                   681295 non-null  int64
#  4   State                                            681295 non-null  object
#  5   District LGD Code                                681295 non-null  int64
#  6   District                                         681295 non-null  object
#  7   Tehsil                                           254823 non-null  object
#  8   Block                                            681295 non-null  object
# ...

# %%
df.shape
# Out:
# (681295, 21)

# %%
df.describe()
# Out:
#                SlNo  State LGD Code  District LGD Code       Latitude  \
# count  681295.00000        681295.0      681295.000000  681295.000000
# mean   340648.00000             3.0         153.881882      30.742214
# std    196673.07016             0.0         239.490135       0.601389
# min         1.00000             3.0          27.000000      29.729444
# 25%    170324.50000             3.0          33.000000      30.313300
# 50%    340648.00000             3.0          38.000000      30.568056
# 75%    510971.50000             3.0          43.000000      31.160833
# max    681295.00000             3.0         662.000000      32.375278
#
#            Longitude  RL_MSL  Groundwater Level Telemetry Quadridaily (meter)
# count  681295.000000     0.0                                    681295.000000
# mean       75.281447     NaN                                       -12.751678
# std         0.740937     NaN                                        46.235618
# ...

# %%
df.columns
# Out:
# Index(['SlNo', 'Station', 'Agency', 'State LGD Code', 'State',
#        'District LGD Code', 'District', 'Tehsil', 'Block', 'Village', 'River',
#        'Basin', 'Tributary', 'Subtributary', 'SubSubtributary', 'Local River',
#        'Latitude', 'Longitude', 'RL_MSL', 'Data Acquisition Time',
#        'Groundwater Level Telemetry Quadridaily (meter)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# SlNo                                                    0
# Station                                                 0
# Agency                                                  0
# State LGD Code                                          0
# State                                                   0
# District LGD Code                                       0
# District                                                0
# Tehsil                                             426472
# Block                                                   0
# Village                                                 0
# River                                                   0
# Basin                                                   0
# Tributary                                               0
# Subtributary                                            0
# SubSubtributary                                         0
# Local River                                             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# SlNo                                                 int64
# Station                                             object
# Agency                                              object
# State LGD Code                                       int64
# State                                               object
# District LGD Code                                    int64
# District                                            object
# Tehsil                                              object
# Block                                               object
# Village                                             object
# River                                               object
# Basin                                               object
# Tributary                                           object
# Subtributary                                        object
# SubSubtributary                                     object
# Local River                                         object
# ...

# %%
df.nunique()
# Out:
# SlNo                                               681295
# Station                                               571
# Agency                                                  1
# State LGD Code                                          1
# State                                                   1
# District LGD Code                                      22
# District                                               22
# Tehsil                                                 41
# Block                                                 158
# Village                                               490
# River                                                   1
# Basin                                                   1
# Tributary                                               1
# Subtributary                                            1
# SubSubtributary                                         1
# Local River                                             1
# ...
