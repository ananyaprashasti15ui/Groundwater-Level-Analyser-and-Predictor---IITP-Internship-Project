# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../../../data/raw/up_groundwater_telemetry.csv')

# %%
df.head()
# Out:
#    SlNo                         Station Agency  State LGD Code          State  \
# 0     1  390713- Jairampur PMS -Shallow   UPGW               9  Uttar Pradesh
# 1     2  390713- Jairampur PMS -Shallow   UPGW               9  Uttar Pradesh
# 2     3  390713- Jairampur PMS -Shallow   UPGW               9  Uttar Pradesh
# 3     4  390713- Jairampur PMS -Shallow   UPGW               9  Uttar Pradesh
# 4     5  390713- Jairampur PMS -Shallow   UPGW               9  Uttar Pradesh
#
#    District LGD Code  District Tehsil Block Village  ... Basin Tributary  \
# 0                187  VARANASI      -     -       -  ...     -         -
# 1                187  VARANASI      -     -       -  ...     -         -
# 2                187  VARANASI      -     -       -  ...     -         -
# 3                187  VARANASI      -     -       -  ...     -         -
# 4                187  VARANASI      -     -       -  ...     -         -
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7433230 entries, 0 to 7433229
# Data columns (total 21 columns):
#  #   Column                                        Dtype
# ---  ------                                        -----
#  0   SlNo                                          int64
#  1   Station                                       object
#  2   Agency                                        object
#  3   State LGD Code                                int64
#  4   State                                         object
#  5   District LGD Code                             int64
#  6   District                                      object
#  7   Tehsil                                        object
#  8   Block                                         object
#  9   Village                                       object
#  10  River                                         object
#  11  Basin                                         object
# ...

# %%
df.shape
# Out:
# (7433230, 21)

# %%
df.describe()
# Out:
#                SlNo  State LGD Code  District LGD Code      Latitude  \
# count  7.433230e+06       7433230.0       7.433230e+06  7.432965e+06
# mean   3.716616e+06             9.0       1.779192e+02  2.698228e+01
# std    2.145789e+06             0.0       1.156439e+02  1.533195e+00
# min    1.000000e+00             9.0       1.180000e+02  2.409871e+01
# 25%    1.858308e+06             9.0       1.330000e+02  2.557000e+01
# 50%    3.716616e+06             9.0       1.520000e+02  2.670464e+01
# 75%    5.574923e+06             9.0       1.700000e+02  2.858966e+01
# max    7.433230e+06             9.0       6.610000e+02  3.013333e+01
#
#           Longitude        RL_MSL  \
# count  7.432965e+06  2.842581e+06
# mean   8.014645e+01  1.763456e+02
# std    2.064870e+00  5.948046e+01
# min    7.302982e+01  6.000000e+01
# 25%    7.825574e+01  1.250000e+02
# 50%    8.008416e+01  1.740000e+02
# 75%    8.188250e+01  2.260000e+02
# max    8.432816e+01  4.000000e+02
#
# ...

# %%
df.columns
# Out:
# Index(['SlNo', 'Station', 'Agency', 'State LGD Code', 'State',
#        'District LGD Code', 'District', 'Tehsil', 'Block', 'Village', 'River',
#        'Basin', 'Tributary', 'Subtributary', 'SubSubtributary', 'Local River',
#        'Latitude', 'Longitude', 'RL_MSL', 'Data Acquisition Time',
#        'Groundwater Level Telemetry 6 Hourly (meter)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# SlNo                                                  0
# Station                                               0
# Agency                                                0
# State LGD Code                                        0
# State                                                 0
# District LGD Code                                     0
# District                                              0
# Tehsil                                                0
# Block                                                 0
# Village                                               0
# River                                                 0
# Basin                                                 0
# Tributary                                             0
# Subtributary                                          0
# SubSubtributary                                       0
# Local River                                           0
# Latitude                                            265
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# SlNo                                              int64
# Station                                          object
# Agency                                           object
# State LGD Code                                    int64
# State                                            object
# District LGD Code                                 int64
# District                                         object
# Tehsil                                           object
# Block                                            object
# Village                                          object
# River                                            object
# Basin                                            object
# Tributary                                        object
# Subtributary                                     object
# SubSubtributary                                  object
# Local River                                      object
# Latitude                                        float64
# ...

# %%
df.nunique()
# Out:
# SlNo                                            7433230
# Station                                            2510
# Agency                                                1
# State LGD Code                                        1
# State                                                 1
# District LGD Code                                    75
# District                                             79
# Tehsil                                              140
# Block                                                19
# Village                                              24
# River                                                 1
# Basin                                                 1
# Tributary                                             1
# Subtributary                                          1
# SubSubtributary                                       1
# Local River                                           1
# Latitude                                           2409
# ...
