# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../data/raw/rainfall.csv")

# %%
df.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# JF              6
# MAM             9
# JJAS           10
# OND            13
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100

#this will give us the percentage of null values
# Out:
# SUBDIVISION    0.000000
# YEAR           0.000000
# JAN            0.095511
# FEB            0.071633
# MAR            0.143266
# APR            0.095511
# MAY            0.071633
# JUN            0.119389
# JUL            0.167144
# AUG            0.095511
# SEP            0.143266
# OCT            0.167144
# NOV            0.262655
# DEC            0.238777
# ANNUAL         0.620821
# JF             0.143266
# MAM            0.214900
# JJAS           0.238777
# OND            0.310411
# dtype: float64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

#this will replace all the null values with mean values

# %%
df.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# JF             0
# MAM            0
# JJAS           0
# OND            0
# dtype: int64

# %%
df.duplicated().sum() 

#this is for checking duplicates
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# SUBDIVISION     object
# YEAR             int64
# JAN            float64
# FEB            float64
# MAR            float64
# APR            float64
# MAY            float64
# JUN            float64
# JUL            float64
# AUG            float64
# SEP            float64
# OCT            float64
# NOV            float64
# DEC            float64
# ANNUAL         float64
# JF             float64
# MAM            float64
# JJAS           float64
# OND            float64
# dtype: object

# %%
df.to_csv("../../data/interim/cleaned_rainfall.csv", index=False)
